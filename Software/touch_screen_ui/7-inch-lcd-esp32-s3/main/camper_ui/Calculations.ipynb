# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

ax = plt.figure().add_subplot()

# Prepare arrays x, y, z
t_param = np.linspace(0 , 1)
Amplitude = 2
freq = 1


#x = 2 * t_param - 1
#y = 1 + Amplitude * np.sin(2*np.pi * freq * t_param)

x = np.cos(t_param)
y = np.sin(t_param)

ax.plot(x, y, label='parametric curve')
ax.legend()

plt.show()
